# %% [markdown]
# # Benchmark Klasik CH₄ / STO-3G
# ### Rigid Scan — HF vs B3LYP vs CASSCF vs CASCI vs FCI
# - **Range 1**: R = 0.50–3.00 Å (16 titik) — CASSCF(4,4), CASCI fixed (orb. CASSCF)
# - **Range 2**: R = 3.00–5.80 Å (16 titik) — CASSCF(4,4), CASCI approx (orb. HF)
# - **Gabungan**: R = 0.50–5.80 Å (31 titik)
#
# **Catatan metodologi:**
# - Geometri: `C(0,0,0), H(0,0,R), H(-0.9073,-0.4964,-0.3511), H(0.6732,0.1673,-0.8436), H(-0.2616,0.9589,0.4528)`
# - FCI(10,9) = referensi eksak dalam basis STO-3G
# - CASCI Range 1: orbital diambil dari hasil CASSCF (CASCI fixed)
# - CASCI Range 2: orbital HF (approx, maxiter=1) — masih perlu diperbaiki

# %%
import matplotlib.pyplot as plt
import numpy as np

# ══════════════════════════════════════════════════════════
# DATA RANGE 1 — R = 0.50–3.00 Å, 16 titik
# CASSCF(4,4), CASCI fixed (baca orbital CASSCF)
# ══════════════════════════════════════════════════════════
R1 = list(np.linspace(0.50, 3.00, 16))

E_HF_1 = [-38.590753477611, -39.276666060660, -39.532617363640, -39.613309561248,
          -39.619934608547, -39.594583280949, -39.556175196474, -39.513857600150,
          -39.472186012913, -39.433482672605, -39.398876862728, -39.368750577144,
          -39.343012398230, -39.321316723946, -39.303220298253, -39.288258469079]

E_DFT_1 = [-38.881485071917, -39.563480530371, -39.817725199412, -39.899580290894,
           -39.910562100912, -39.892519484148, -39.863680966380, -39.832283700154,
           -39.802004087261, -39.774477409474, -39.750383963337, -39.729861409066,
           -39.712727504120, -39.698636540532, -39.687207741963, -39.678060018491]

E_CASSCF_1 = [-38.628820279594, -39.314672294710, -39.570184723838, -39.650386088465,
              -39.656553155152, -39.630776480821, -39.591957832144, -39.549235555453,
              -39.582255537758, -39.569721539045, -39.561815576783, -39.557162875256,
              -39.554538435502, -39.553091701964, -39.552304935046, -39.551882425184]

# CASCI fixed: baca orbital dari CASSCF
E_CASCI_1 = [-38.628820279594, -39.314753615463, -39.570156135764, -39.650386088465,
             -39.656550312280, -39.630783358389, -39.591957832144, -39.549226972549,
             -39.582258583321, -39.569721539045, -39.561814367331, -39.557163567790,
             -39.554538435502, -39.553091491089, -39.552305049174, -39.551882425184]

E_FCI_1 = [-38.661283721798, -39.350893073326, -39.610906058699, -39.696930396531,
           -39.711016490486, -39.696174728435, -39.672169701901, -39.648571140854,
           -39.629544229618, -39.616084021462, -39.607449208008, -39.602281543939,
           -39.599321692317, -39.597669082314, -39.596761508634, -39.596270730145]

# ══════════════════════════════════════════════════════════
# DATA RANGE 2 — R = 3.00–5.80 Å, 16 titik
# CASSCF(4,4), CASCI approx (orb. HF, maxiter=1)
# ══════════════════════════════════════════════════════════
R2 = list(np.linspace(3.00, 5.80, 16))

E_HF_2 = [-39.288259310646, -39.274665112793, -39.263829464482, -39.255193542590,
          -39.248271746544, -39.242661000101, -39.238045459732, -39.234177989654,
          -39.230877095157, -39.228008809243, -39.225476606288, -39.223207621148,
          -39.221150189029, -39.219266188635, -39.217528011516, -39.215914482106]

E_DFT_2 = [-39.678060017924, -39.670088477999, -39.664084670802, -39.659608573034,
           -39.656293331655, -39.653861268284, -39.652065315506, -39.650698999739,
           -39.649639147140, -39.648812002810, -39.648158215170, -39.647629011206,
           -39.647178349847, -39.646773802601, -39.646402653329, -39.646061342604]

E_CASSCF_2 = [-39.551914149360, -39.551655020831, -39.551531186964, -39.551473717228,
              -39.551447638708, -39.551436186564, -39.551431321791, -39.551429311733,
              -39.551428357232, -39.551428163216, -39.551427999610, -39.551427919941,
              -39.551427878850, -39.551427856449, -39.551427843664, -39.551427836245]

# CASCI fixed Range 2: orbital CASSCF (dari CH4_CASCI_fixed_R2.*.out)
E_CASCI_2 = [-39.551914149360, -39.551654989395, -39.551531201733, -39.551473717228,
             -39.551447635619, -39.551436187933, -39.551431321791, -39.551429311488,
             -39.551428357346, -39.551428163216, -39.551427999590, -39.551427919951,
             -39.551427878850, -39.551427856445, -39.551427843666, -39.551427836245]

E_FCI_2 = [-39.596270730819, -39.595988753261, -39.595853604291, -39.595790643725,
           -39.595762115794, -39.595749526441, -39.595744113381, -39.595741848976,
           -39.595740929762, -39.595740568706, -39.595740431796, -39.595740381405,
           -39.595740363433, -39.595740357078, -39.595740354888, -39.595740354118]

# ══════════════════════════════════════════════════════════
# DATA GABUNGAN (skip titik R=3.00 dari Range 2 — duplikat)
# ══════════════════════════════════════════════════════════
R_gab        = R1 + R2[1:]
E_HF_gab     = E_HF_1     + E_HF_2[1:]
E_DFT_gab    = E_DFT_1    + E_DFT_2[1:]
E_CASSCF_gab = E_CASSCF_1 + E_CASSCF_2[1:]
E_CASCI_gab  = E_CASCI_1  + E_CASCI_2[1:]
E_FCI_gab    = E_FCI_1    + E_FCI_2[1:]

print(f'Jumlah titik Range 1  : {len(R1)}')
print(f'Jumlah titik Range 2  : {len(R2)}')
print(f'Jumlah titik Gabungan : {len(R_gab)}')

# %% [markdown]
# ## Plot 1 — Range 1: R = 0.50–3.00 Å

# %%
def ringkasan_energi(R, datasets, judul):
    """Cetak tabel ringkasan energi elektronik per metode."""
    print('='*72)
    print(f'RINGKASAN ENERGI ELEKTRONIK CH₄ (STO-3G) — {judul}')
    print('='*72)
    print(f'{"Metode":<28} {"E (R_min) (Ha)":>15} {"E (R_max) (Ha)":>15} {"ΔE (Ha)":>10}')
    print('-'*72)
    for nama, E in datasets.items():
        delta = abs(E[-1] - E[0])
        print(f'{nama:<28} {E[0]:>15.6f} {E[-1]:>15.6f} {delta:>10.6f}')
    print('='*72)
    print(f'ΔE = |E(R={R[-1]:.2f} Å) − E(R={R[0]:.2f} Å)|')


def plot_ch4(R, E_HF, E_DFT, E_CASSCF, E_CASCI, E_FCI,
             title_suffix, xlim,
             casci_label='CASCI fixed (orb. CASSCF)/STO-3G'):
    """Helper fungsi plot PES + Error CH4 — reusable untuk 3 range."""

    e_ref        = np.array(E_FCI)
    error_hf     = np.abs(np.array(E_HF)     - e_ref)
    error_dft    = np.abs(np.array(E_DFT)    - e_ref)
    error_casscf = np.abs(np.array(E_CASSCF) - e_ref)
    error_casci  = np.abs(np.array(E_CASCI)  - e_ref)
    CA = 0.0016

    idx_fci = list(E_FCI).index(min(E_FCI))

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    fig.patch.set_facecolor('white')

    # ── Panel Kiri: PES ──
    ax1.plot(R, E_HF,    'o-',  color='steelblue', linewidth=2,
             markersize=6, markerfacecolor='white', markeredgewidth=2,
             label='HF/STO-3G')
    ax1.plot(R, E_DFT,   'D-',  color='purple',    linewidth=2,
             markersize=6, markerfacecolor='white', markeredgewidth=2,
             label='B3LYP/STO-3G')
    ax1.plot(R, E_CASSCF,'s--', color='green',     linewidth=2,
             markersize=6, markerfacecolor='white', markeredgewidth=2,
             label='CASSCF(4,4)/STO-3G')
    ax1.plot(R, E_CASCI, 'v-',  color='brown',     linewidth=2,
             markersize=6, markerfacecolor='white', markeredgewidth=2,
             label=casci_label)
    ax1.plot(R, E_FCI,   'x-',  color='red',       linewidth=2,
             markersize=8, markeredgewidth=2,
             label='FCI(10,9)/STO-3G (Eksak)')

    ax1.plot(R[idx_fci], E_FCI[idx_fci], 'r*', markersize=14, zorder=5)
    ax1.annotate(f'R_eq = {R[idx_fci]:.2f} Å\nE = {E_FCI[idx_fci]:.4f} Ha',
                 xy=(R[idx_fci], E_FCI[idx_fci]),
                 xytext=(R[idx_fci]+0.3, E_FCI[idx_fci]+0.3),
                 arrowprops=dict(arrowstyle='->', color='black', lw=1.2),
                 fontsize=9,
                 bbox=dict(boxstyle='round,pad=0.3', facecolor='white', edgecolor='black'))

    ax1.axvline(x=1.089, color='gray', linestyle='--', linewidth=1.5, alpha=0.7,
                label='Eksperimen C-H = 1.089 Å')
    ax1.set_xlim(xlim)
    ax1.set_xlabel('Panjang Ikatan C-H (Å)', fontsize=12)
    ax1.set_ylabel('Energi (Ha)', fontsize=12)
    ax1.set_title('Potential Energy Surface — CH₄\nHF vs B3LYP vs CASSCF vs CASCI vs FCI [STO-3G]',
                  fontsize=10)
    ax1.legend(fontsize=7.5, loc='upper right')
    ax1.grid(True, alpha=0.25)

    # ── Panel Kanan: Error vs FCI ──
    ax2.semilogy(R, error_hf     + 1e-10, 'o-',  color='steelblue', linewidth=2,
                 markersize=6, markerfacecolor='white', markeredgewidth=2,
                 label='|E_HF − E_FCI|')
    ax2.semilogy(R, error_dft    + 1e-10, 'D-',  color='purple',    linewidth=2,
                 markersize=6, markerfacecolor='white', markeredgewidth=2,
                 label='|E_B3LYP − E_FCI|')
    ax2.semilogy(R, error_casscf + 1e-10, 's--', color='green',     linewidth=2,
                 markersize=6, markerfacecolor='white', markeredgewidth=2,
                 label='|E_CASSCF − E_FCI|')
    ax2.semilogy(R, error_casci  + 1e-10, 'v-',  color='brown',     linewidth=2,
                 markersize=6, markerfacecolor='white', markeredgewidth=2,
                 label='|E_CASCI − E_FCI|')
    ax2.axhline(y=CA, color='gray', linestyle='--', linewidth=1.8,
                label='Chemical accuracy (1.6 mHa)')

    ax2.set_xlim(xlim)
    ax2.set_xlabel('Panjang Ikatan C-H (Å)', fontsize=12)
    ax2.set_ylabel('|E_metode − E_FCI| (Ha)', fontsize=12)
    ax2.set_title('Error Energi terhadap FCI — CH₄\nHF vs B3LYP vs CASSCF vs CASCI [STO-3G]',
                  fontsize=10)
    ax2.legend(fontsize=7.5, bbox_to_anchor=(1.01, 1.0), loc='upper left', borderaxespad=0)
    ax2.grid(True, alpha=0.25, which='both')

    plt.suptitle(f'Benchmark Klasik CH₄ / STO-3G  {title_suffix}',
                 fontsize=13, weight='bold', y=1.02)
    plt.tight_layout()
    fname = f'Benchmark_CH4_{title_suffix.replace(" ","_").replace("[","").replace("]","").replace("–","-")}.png'
    plt.savefig(fname, dpi=150, bbox_inches='tight')
    plt.show()
    print(f'Tersimpan: {fname}')

# ── Plot Range 1 ──
plot_ch4(R1, E_HF_1, E_DFT_1, E_CASSCF_1, E_CASCI_1, E_FCI_1,
         '[Rigid Scan, R = 0.50–3.00 Å]',
         xlim=(0.4, 3.1),
         casci_label='CASCI fixed (orb. CASSCF)/STO-3G')

# %%
# ── Ringkasan Energi Range 1 ──
ringkasan_energi(R1, {
    'HF':                    E_HF_1,
    'B3LYP':                 E_DFT_1,
    'CASSCF(4,4)':           E_CASSCF_1,
    'CASCI fixed (orb.CASSCF)': E_CASCI_1,
    'FCI(10,9)':             E_FCI_1,
}, 'R = 0.50–3.00 Å')

# %% [markdown]
# ## Plot 2 — Range 2: R = 3.00–5.80 Å

# %%
plot_ch4(R2, E_HF_2, E_DFT_2, E_CASSCF_2, E_CASCI_2, E_FCI_2,
         '[Rigid Scan, R = 3.00–5.80 Å]',
         xlim=(2.9, 5.9),
         casci_label='CASCI fixed (orb. CASSCF)/STO-3G')

# %%
# ── Ringkasan Energi Range 2 ──
ringkasan_energi(R2, {
    'HF':                      E_HF_2,
    'B3LYP':                   E_DFT_2,
    'CASSCF(4,4)':             E_CASSCF_2,
    'CASCI fixed (orb. CASSCF)': E_CASCI_2,
    'FCI(10,9)':               E_FCI_2,
}, 'R = 3.00–5.80 Å')

# %% [markdown]
# ## Plot 3 — Gabungan: R = 0.50–5.80 Å

# %%
plot_ch4(R_gab, E_HF_gab, E_DFT_gab, E_CASSCF_gab, E_CASCI_gab, E_FCI_gab,
         '[Rigid Scan, R = 0.50–5.80 Å]',
         xlim=(0.4, 5.9),
         casci_label='CASCI/STO-3G (fixed R1 + fixed R2)')

# %%
# ── Ringkasan Energi Gabungan ──
ringkasan_energi(R_gab, {
    'HF':                      E_HF_gab,
    'B3LYP':                   E_DFT_gab,
    'CASSCF(4,4)':             E_CASSCF_gab,
    'CASCI':                   E_CASCI_gab,
    'FCI(10,9)':               E_FCI_gab,
}, 'R = 0.50–5.80 Å (Gabungan)')
